# %%
from tensorflow.keras.layers import Conv2D, Convolution2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Normalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam,SGD

import warnings
warnings.filterwarnings("ignore")

# %%
model=Sequential()
#1
model.add(Convolution2D(96,11,padding="valid", 
          strides=(4,4),
          input_shape=(224,224,3),
          activation="relu"))


model.add(MaxPooling2D(pool_size=(3,3),
                      strdies=(2,2),
                      pading="valid"))

model.add(BatchNormalization())


#2
model.add(Convolution2D(256,5,padding="valid", 
          strides=(1,1),
          activation="relu"))


model.add(MaxPooling2D(pool_size=(3,3),
                      strdies=(2,2),
                      pading="valid"))

model.add(BatchNormalization())


#3
model.add(Convolution2D(384,5,
          padding="valid", 
          strides=(1,1),
          activation="relu"))
model.add(BatchNormalization())


#4
model.add(MaxPooling2D(384,3,
                      pading="valid",
                      strdies=(1,1),
                      activation="relu"))

model.add(BatchNormalization())



#5
model.add(Convolution2D(256,3,
                      pading="valid",
                      strdies=(1,1),
                      activation="relu"))

model.add(MaxPooling2D(pool_size=3,
                       strides=(2,2),
                      padding="valid"))
                      
model.add(BatchNormalization())

#Flatten
model.add(Flatten())


#Dense1
model.add(Dense(4096, activation="relu"))
model.add(Dropout(0.2))
