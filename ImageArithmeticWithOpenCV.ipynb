# %%
import tensorflow as tf
import os
import cv2
import imghdr
import warnings
import numpy as np
warnings.filterwarnings('ignore')

# %%
def plt_imshow(title,image):
    image=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.imshow(image)
    plt.title("Dog Image")
    plt.grid(True)
    plt.show()

# %%
args={"image":"dogimage.jpg","scharr":0}
img=cv2.imread("dogimage.jpg",cv2.COLOR_BGR2GRAY)

# %%
img=cv2.imread("dogimage.jpg")
# img.shape

# %%
imageAddCustomValue=cv2.add(np.uint8([200]), np.uint8([100]))
imageSubtractionCustomValue=cv2.subtract(np.uint8([50]), np.uint8([100]))

# %%
print("Image maximum Value of 255 {}".format(imageAddCustomValue))
print("Image maximum Value of 255 {}".format(imageSubtractionCustomValue))
# Out:
# Image maximum Value of 255 [[255]]
# Image maximum Value of 255 [[0]]

# %%
# do with numpy
imageAddCustomValue=cv2.add(np.uint8([200]), np.uint8([100]))
imageSubtractionCustomValue=np.uint8([50])-np.uint([100])

# %%
print("Image maximum Value of 255 {}".format(imageAddCustomValue))
print("Image minimum Value of 255 {}".format(imageSubtractionCustomValue))
# Out:
# Image maximum Value of 255 [[255]]
# Image minimum Value of 255 [4294967246]

# %%
img=cv2.imread(args['image'])
img.shape
# Out:
# (333, 516, 3)

# %%
cv2.imread("dogimage.jpg")
# Out:
# array([[[  0,  63,  51],
#         [  0,  62,  50],
#         [  0,  60,  46],
#         ...,
#         [  3,  51,  39],
#         [  4,  50,  38],
#         [  5,  48,  37]],
#
#        [[  0,  62,  50],
#         [  0,  60,  49],
#         [  0,  59,  45],
#         ...,
#         [  5,  55,  43],
#         [  5,  53,  41],
#         [  5,  51,  39]],
#
#        [[  1,  59,  48],
#         [  0,  58,  47],
#         [  2,  56,  43],
#         ...,
#         [  4,  57,  44],
#         [  3,  53,  41],
#         [  3,  50,  41]],
#
#        ...,
#
#        [[ 44, 161, 138],
#         [ 45, 161, 138],
#         [ 51, 162, 140],
#         ...,
#         [ 58, 147, 137],
#         [ 58, 147, 137],
#         [ 56, 145, 136]],
#
#        [[ 40, 162, 138],
#         [ 41, 161, 137],
#         [ 46, 162, 139],
#         ...,
#         [ 56, 148, 137],
#         [ 56, 147, 138],
#         [ 57, 147, 141]],
#
#        [[ 38, 162, 138],
#         [ 39, 161, 137],
#         [ 43, 160, 137],
# ...

# %%
m=np.ones(img.shape, dtype=np.uint8)*100
m
# Out:
# array([[[100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100],
#         ...,
#         [100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100]],
#
#        [[100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100],
#         ...,
#         [100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100]],
#
#        [[100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100],
#         ...,
#         [100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100]],
#
#        ...,
#
#        [[100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100],
#         ...,
#         [100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100]],
#
#        [[100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100],
#         ...,
#         [100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100]],
#
#        [[100, 100, 100],
#         [100, 100, 100],
#         [100, 100, 100],
# ...

# %%
add=cv2.add(img,m)

# %%
import matplotlib.pyplot as plt

# %%
plt_imshow("Added value",add)

# %%
sub=cv2.subtract(img,m)
plt_imshow("Subtracted value",sub)
